# %% [markdown]
# # Is there any association between a particular type of opioid and number of overdose deaths?

# %%
from sqlalchemy import create_engine
import pandas as pd
import plotly.express as px

# %%
connection_string = "postgres://postgres:postgres@localhost:5432/prescribers"

# %%
engine = create_engine(connection_string)

# %%
drug_query = '''
WITH zip_to_county AS (
	SELECT
		zf.fipscounty
		, fc.county
		, fc.state
		, zip
		, tot_ratio
		, RANK() OVER(PARTITION BY zip ORDER BY tot_ratio DESC) AS rnk
	FROM zip_fips AS zf
	JOIN fips_county AS fc
		ON fc.fipscounty = zf.fipscounty
	WHERE fc.state = 'TN'
)

SELECT zc.fipscounty
	, zc.county
	, zc.state
	, p3.population
	, d.generic_name
	, d.long_acting_opioid_drug_flag
	, SUM(p2.total_claim_count) AS tot_scripts
	, ROUND(SUM(p2.total_claim_count) / p3.population * 10000, 6) AS scripts_per_10k
	
FROM zip_to_county AS zc

JOIN prescriber AS p1
	ON p1.nppes_provider_zip5 = zc.zip

JOIN prescription AS p2
	ON p2.npi = p1.npi

JOIN drug AS d
	ON d.drug_name = p2.drug_name

JOIN population AS p3
	ON zc.fipscounty = p3.fipscounty

WHERE
	zc.rnk = 1
	AND d.opioid_drug_flag = 'Y'

GROUP BY 1,2,3,4,5,6
ORDER BY 4 DESC
;
'''
drug_result = engine.execute(drug_query)

# %%
opioids = pd.read_sql(drug_query, con = engine)
opioids.head()
# Out:
#   fipscounty  county state  population                   generic_name  \
# 0      47157  SHELBY    TN    937847.0     ACETAMINOPHEN WITH CODEINE
# 1      47157  SHELBY    TN    937847.0  ACETAMINOPHEN/CAFF/DIHYDROCOD
# 2      47157  SHELBY    TN    937847.0                  BUPRENORPHINE
# 3      47157  SHELBY    TN    937847.0           BUTORPHANOL TARTRATE
# 4      47157  SHELBY    TN    937847.0                CODEINE SULFATE
#
#   long_acting_opioid_drug_flag  tot_scripts  scripts_per_10k
# 0                            N       6864.0        73.188910
# 1                            N         12.0         0.127953
# 2                            Y        339.0         3.614662
# 3                            N        131.0         1.396816
# 4                            N         12.0         0.127953

# %%
od_query = '''
SELECT
	fc.fipscounty
	, od.overdose_deaths AS num_ods_2017
	, ROUND((od.overdose_deaths / p3.population * 10000), 6) AS od_rate_per_10K_2017

FROM overdose_deaths AS od

JOIN fips_county AS fc
	ON fc.fipscounty = od.fipscounty

JOIN population AS p3
	ON p3.fipscounty = od.fipscounty

WHERE od.year = 2017
AND fc.state = 'TN'
;
'''

# %%
ods = pd.read_sql(od_query, con = engine)
ods.head()
# Out:
#   fipscounty  num_ods_2017  od_rate_per_10k_2017
# 0      47017           2.0              0.710808
# 1      47023           1.0              0.584898
# 2      47039           0.0              0.000000
# 3      47037         184.0              2.712576
# 4      47087           2.0              1.728160

# %%
oao = opioids.merge(ods, how = 'outer', on = 'fipscounty')
oao.head()
# Out:
#   fipscounty  county state  population                   generic_name  \
# 0      47157  SHELBY    TN    937847.0     ACETAMINOPHEN WITH CODEINE
# 1      47157  SHELBY    TN    937847.0  ACETAMINOPHEN/CAFF/DIHYDROCOD
# 2      47157  SHELBY    TN    937847.0                  BUPRENORPHINE
# 3      47157  SHELBY    TN    937847.0           BUTORPHANOL TARTRATE
# 4      47157  SHELBY    TN    937847.0                CODEINE SULFATE
#
#   long_acting_opioid_drug_flag  tot_scripts  scripts_per_10k  num_ods_2017  \
# 0                            N       6864.0        73.188910         159.0
# 1                            N         12.0         0.127953         159.0
# 2                            Y        339.0         3.614662         159.0
# 3                            N        131.0         1.396816         159.0
# 4                            N         12.0         0.127953         159.0
#
#    od_rate_per_10k_2017
# 0              1.695372
# 1              1.695372
# 2              1.695372
# 3              1.695372
# 4              1.695372

# %%
# Create a boxplot to see 
fig = px.box(oao,
                 x = 'generic_name',
                 y = 'scripts_per_10k'
            )
fig.show()
# Out:
# <div>                            <div id="d3e802fb-4b8d-4ac5-a5c5-fef6f3da1c8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3e802fb-4b8d-4ac5-a5c5-fef6f3da1c8f")) {                    Plotly.newPlot(                        "d3e802fb-4b8d-4ac5-a5c5-fef6f3da1c8f",                        [{"alignmentgroup": "True", "hovertemplate": "generic_name=%{x}<br>scripts_per_10k=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["ACETAMINOPHEN WITH CODEINE", "ACETAMINOPHEN/CAFF/DIHYDROCOD", "BUPRENORPHINE", "BUTORPHANOL TARTRATE", "CODEINE SULFATE", "CODEINE/BUTALBITAL/ASA/CAFFEIN", "FENTANYL", "HYDROCODONE BITARTRATE", "HYDROCODONE/ACETAMINOPHEN", "HYDROCODONE/IBUPROFEN", "HYDROMORPHONE HCL", "HYDROMORPHONE HCL", "MEPERIDINE HCL", "METHADONE HCL", "MORPHINE SULFATE", "MORPHINE SULFATE", "MORPHINE SULFATE/NALTREXONE", "OXYCODONE HCL", "OXYCODONE HCL", "OXYCODONE HCL/ACETAMINOPHEN", "OXYCODONE MYRISTATE", "OXYMORPHONE HCL", "OXYMORPHONE HCL", "TAPENTADOL HCL", "TAPENTADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL/ACETAMINOPHEN", "ACETAMINOPHEN WITH CODEINE", "BUPRENORPHINE", "BUTALBIT/ACETAMIN/CAFF/CODEINE", "BUTORPHANOL TARTRATE", "CODEINE SULFATE", "CODEINE/BUTALBITAL/ASA/CAFFEIN", "FENTANYL", "HYDROCODONE BITARTRATE", "HYDROCODONE/ACETAMINOPHEN", "HYDROCODONE/IBUPROFEN", "HYDROMORPHONE HCL", "HYDROMORPHONE HCL", "MEPERIDINE HCL", "METHADONE HCL", "MORPHINE SULFATE", "MORPHINE SULFATE", "MORPHINE SULFATE/NALTREXONE", "OXYCODONE HCL", "OXYCODONE HCL", "OXYCODONE HCL/ACETAMINOPHEN", "OXYCODONE MYRISTATE", "OXYMORPHONE HCL", "OXYMORPHONE HCL", "PENTAZOCINE HCL/NALOXONE HCL", "TAPENTADOL HCL", "TAPENTADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL/ACETAMINOPHEN", "ACETAMINOPHEN WITH CODEINE", "ACETAMINOPHEN/CAFF/DIHYDROCOD", "BUPRENORPHINE", "BUTALBIT/ACETAMIN/CAFF/CODEINE", "BUTORPHANOL TARTRATE", "CODEINE/BUTALBITAL/ASA/CAFFEIN", "FENTANYL", "HYDROCODONE BITARTRATE", "HYDROCODONE/ACETAMINOPHEN", "HYDROCODONE/IBUPROFEN", "HYDROMORPHONE HCL", "HYDROMORPHONE HCL", "MEPERIDINE HCL", "METHADONE HCL", "MORPHINE SULFATE", "MORPHINE SULFATE", "MORPHINE SULFATE/NALTREXONE", "OXYCODONE HCL", "OXYCODONE HCL", "OXYCODONE HCL/ACETAMINOPHEN", "OXYCODONE MYRISTATE", "OXYMORPHONE HCL", "OXYMORPHONE HCL", "PENTAZOCINE HCL/NALOXONE HCL", "TAPENTADOL HCL", "TAPENTADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL/ACETAMINOPHEN", "ACETAMINOPHEN WITH CODEINE", "BUPRENORPHINE", "BUTALBIT/ACETAMIN/CAFF/CODEINE", "BUTORPHANOL TARTRATE", "CODEINE/BUTALBITAL/ASA/CAFFEIN", "FENTANYL", "HYDROCODONE BITARTRATE", "HYDROCODONE/ACETAMINOPHEN", "HYDROCODONE/IBUPROFEN", "HYDROMORPHONE HCL", "HYDROMORPHONE HCL", "MEPERIDINE HCL", "METHADONE HCL", "MORPHINE SULFATE", "MORPHINE SULFATE", "MORPHINE SULFATE/NALTREXONE", "OXYCODONE HCL", "OXYCODONE HCL", "OXYCODONE HCL/ACETAMINOPHEN", "OXYCODONE HCL/ASPIRIN", "OXYCODONE MYRISTATE", "OXYMORPHONE HCL", "OXYMORPHONE HCL", "TAPENTADOL HCL", "TAPENTADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL/ACETAMINOPHEN", "ACETAMINOPHEN WITH CODEINE", "BUPRENORPHINE", "BUTORPHANOL TARTRATE", "FENTANYL", "FENTANYL", "HYDROCODONE BITARTRATE", "HYDROCODONE/ACETAMINOPHEN", "HYDROMORPHONE HCL", "HYDROMORPHONE HCL", "METHADONE HCL", "MORPHINE SULFATE", "MORPHINE SULFATE", "MORPHINE SULFATE/NALTREXONE", "OXYCODONE HCL", "OXYCODONE HCL", "OXYCODONE HCL/ACETAMINOPHEN", "OXYMORPHONE HCL", "OXYMORPHONE HCL", "TAPENTADOL HCL", "TAPENTADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL/ACETAMINOPHEN", "ACETAMINOPHEN WITH CODEINE", "ACETAMINOPHEN/CAFF/DIHYDROCOD", "BUPRENORPHINE", "BUTALBIT/ACETAMIN/CAFF/CODEINE", "BUTORPHANOL TARTRATE", "FENTANYL", " ...

# %%
oao.corr()
# Out:
#                       population  tot_scripts  scripts_per_10k  num_ods_2017  \
# population              1.000000     0.280214        -0.080190      0.910905
# tot_scripts             0.280214     1.000000         0.480700      0.283490
# scripts_per_10k        -0.080190     0.480700         1.000000     -0.069313
# num_ods_2017            0.910905     0.283490        -0.069313      1.000000
# od_rate_per_10k_2017    0.236303     0.090853        -0.036091      0.426827
#
#                       od_rate_per_10k_2017
# population                        0.236303
# tot_scripts                       0.090853
# scripts_per_10k                  -0.036091
# num_ods_2017                      0.426827
# od_rate_per_10k_2017              1.000000
