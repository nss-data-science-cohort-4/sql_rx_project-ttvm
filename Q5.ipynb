# %% [markdown]
# # Is there any association between a particular type of opioid and number of overdose deaths?

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
connection_string = "postgres://postgres:postgres@localhost:5432/prescribers"

# %%
engine = create_engine(connection_string)

# %%
drug_query = '''
WITH zip_to_county AS (
	SELECT
		zf.fipscounty
		, fc.county
		, fc.state
		, zip
		, tot_ratio
		, RANK() OVER(PARTITION BY zip ORDER BY tot_ratio DESC) AS rnk
	FROM zip_fips AS zf
	JOIN fips_county AS fc
		ON fc.fipscounty = zf.fipscounty
	WHERE fc.state = 'TN'
)

SELECT zc.fipscounty
	, zc.county
	, zc.state
	, p3.population
	, d.generic_name
	, d.long_acting_opioid_drug_flag
    , RANK() OVER(PARTITION BY fipscounty ORDER BY SUM(p2.total_claim_count) DESC) AS rnk
	, SUM(p2.total_claim_count) AS tot_opioid_scripts
	, ROUND(SUM(p2.total_claim_count) / SUM(p3.population) * 10000, 6) AS scripts_per_10k
	
FROM zip_to_county AS zc

JOIN prescriber AS p1
	ON p1.nppes_provider_zip5 = zc.zip

JOIN prescription AS p2
	ON p2.npi = p1.npi

JOIN drug AS d
	ON d.drug_name = p2.drug_name

JOIN population AS p3
	ON zc.fipscounty = p3.fipscounty

WHERE
	zc.rnk = 1
	AND d.opioid_drug_flag = 'Y'

GROUP BY 1,2,3,4,5,6
ORDER BY 4 DESC
;
'''
drug_result = engine.execute(drug_query)
# Out:
# ---------------------------------------------------------------------------
# AmbiguousColumn                           Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# AmbiguousColumn: column reference "fipscounty" is ambiguous
# LINE 22:     , RANK() OVER(PARTITION BY fipscounty ORDER BY SUM(p2.to...
#                                         ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-10-61b2a0b44934> in <module>
#      46 ;
#      47 '''
# ---> 48 drug_result = engine.execute(drug_query)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2236
#    2237         connection = self._contextual_connect(close_with_result=True)
# -> 2238         return connection.execute(statement, *multiparams, **params)
#    2239
#    2240     def scalar(self, statement, *multiparams, **params):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1004         """
#    1005         if isinstance(object_, util.string_types[0]):
# -> 1006             return self._execute_text(object_, multiparams, params)
#    1007         try:
#    1008             meth = object_._execute_on_connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1173         dialect = self.dialect
#    1174         parameters = _distill_params(multiparams, params)
# -> 1175         ret = self._execute_context(
#    1176             dialect,
#    1177             dialect.execution_ctx_cls._init_statement,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                             break
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#    1279                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.AmbiguousColumn) column reference "fipscounty" is ambiguous
# LINE 22:     , RANK() OVER(PARTITION BY fipscounty ORDER BY SUM(p2.to...
#                                         ^
#
# [SQL:
# WITH zip_to_county AS (
# 	SELECT
# 		zf.fipscounty
# 		, fc.county
# 		, fc.state
# 		, zip
# 		, tot_ratio
# 		, RANK() OVER(PARTITION BY zip ORDER BY tot_ratio DESC) AS rnk
# 	FROM zip_fips AS zf
# 	JOIN fips_county AS fc
# 		ON fc.fipscounty = zf.fipscounty
# 	WHERE fc.state = 'TN'
# )
#
# SELECT zc.fipscounty
# 	, zc.county
# 	, zc.state
# 	, p3.population
# 	, d.generic_name
# 	, d.long_acting_opioid_drug_flag
#     , RANK() OVER(PARTITION BY fipscounty ORDER BY SUM(p2.total_claim_count) DESC) AS rnk
# 	, SUM(p2.total_claim_count) AS tot_opioid_scripts
# 	, ROUND(SUM(p2.total_claim_count) / SUM(p3.population) * 10000, 6) AS scripts_per_10k
#
# FROM zip_to_county AS zc
#
# JOIN prescriber AS p1
# 	ON p1.nppes_provider_zip5 = zc.zip
#
# JOIN prescription AS p2
# 	ON p2.npi = p1.npi
#
# JOIN drug AS d
# 	ON d.drug_name = p2.drug_name
#
# JOIN population AS p3
# 	ON zc.fipscounty = p3.fipscounty
#
# WHERE
# 	zc.rnk = 1
# 	AND d.opioid_drug_flag = 'Y'
#
# GROUP BY 1,2,3,4,5,6
# ORDER BY 4 DESC
# ;
# ]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
opioids = pd.read_sql(drug_query, con = engine)
opioids.head()
# Out:
#   fipscounty  county state  population                   generic_name  \
# 0      47157  SHELBY    TN    937847.0     ACETAMINOPHEN WITH CODEINE
# 1      47157  SHELBY    TN    937847.0  ACETAMINOPHEN/CAFF/DIHYDROCOD
# 2      47157  SHELBY    TN    937847.0                  BUPRENORPHINE
# 3      47157  SHELBY    TN    937847.0           BUTORPHANOL TARTRATE
# 4      47157  SHELBY    TN    937847.0                CODEINE SULFATE
#
#   long_acting_opioid_drug_flag  tot_opioid_scripts  scripts_per_10k
# 0                            N              6864.0         0.369641
# 1                            N                12.0         0.127953
# 2                            Y               339.0         0.258190
# 3                            N               131.0         0.279363
# 4                            N                12.0         0.127953

# %%
od_query = '''
SELECT
	fc.fipscounty
	, od.overdose_deaths AS num_ods_2017
	, ROUND((od.overdose_deaths / p3.population * 10000), 6) AS od_rate_per_10K_2017

FROM overdose_deaths AS od

JOIN fips_county AS fc
	ON fc.fipscounty = od.fipscounty

JOIN population AS p3
	ON p3.fipscounty = od.fipscounty

WHERE od.year = 2017
AND fc.state = 'TN'
;
'''

# %%
ods = pd.read_sql(od_query, con = engine)
ods.head()
# Out:
#   fipscounty  num_ods_2017  od_rate_per_10k_2017
# 0      47017           2.0              0.710808
# 1      47023           1.0              0.584898
# 2      47039           0.0              0.000000
# 3      47037         184.0              2.712576
# 4      47087           2.0              1.728160

# %%
oao = opioids.merge(ods, how = 'outer', on = 'fipscounty')
oao.head()
# Out:
#   fipscounty  county state  population                   generic_name  \
# 0      47157  SHELBY    TN    937847.0     ACETAMINOPHEN WITH CODEINE
# 1      47157  SHELBY    TN    937847.0  ACETAMINOPHEN/CAFF/DIHYDROCOD
# 2      47157  SHELBY    TN    937847.0                  BUPRENORPHINE
# 3      47157  SHELBY    TN    937847.0           BUTORPHANOL TARTRATE
# 4      47157  SHELBY    TN    937847.0                CODEINE SULFATE
#
#   long_acting_opioid_drug_flag  tot_opioid_scripts  scripts_per_10k  \
# 0                            N              6864.0         0.369641
# 1                            N                12.0         0.127953
# 2                            Y               339.0         0.258190
# 3                            N               131.0         0.279363
# 4                            N                12.0         0.127953
#
#    num_ods_2017  od_rate_per_10k_2017
# 0         159.0              1.695372
# 1         159.0              1.695372
# 2         159.0              1.695372
# 3         159.0              1.695372
# 4         159.0              1.695372
