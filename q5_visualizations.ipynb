# %% [markdown]
# # Is there any association between a particular type of opioid and number of overdose deaths?

# %% [markdown]
# ### Import libraries and data from the prescribers database

# %%
# import statements
from sqlalchemy import create_engine
import pandas as pd
import plotly.express as px

# %%
# establish path to prescribers database
connection_string = "postgres://postgres:postgres@localhost:5432/prescribers"

# %%
# define SQL query engine
engine = create_engine(connection_string)

# %%
# get opioid drug data from the prescribers database
drug_query = '''
WITH zip_to_county AS (
	SELECT
		zf.fipscounty
		, fc.county
		, fc.state
		, zip
		, tot_ratio
		, RANK() OVER(PARTITION BY zip ORDER BY tot_ratio DESC) AS rnk
	FROM zip_fips AS zf
	JOIN fips_county AS fc
		ON fc.fipscounty = zf.fipscounty
	WHERE fc.state = 'TN'
)

SELECT zc.fipscounty
	, zc.county
	, zc.state
	, p3.population
	, d.generic_name
	, CASE WHEN d.opioid_drug_flag = 'Y' AND d.generic_name LIKE 'HYDROCODONE%%' THEN 'HYDROCODONE (ALL)'
        WHEN d.opioid_drug_flag = 'Y' AND d.generic_name LIKE 'METHADONE%%' THEN 'METHADONE (ALL)'
        WHEN d.opioid_drug_flag = 'Y' AND d.generic_name LIKE 'OXYCODONE%%' THEN 'OXYCODONE (ALL)'
        WHEN d.opioid_drug_flag = 'N' THEN 'NOT AN OPIOID'
        ELSE 'NOT A TOP 3 OPIOID'
        END AS drug_group
    , d.opioid_drug_flag
	, d.long_acting_opioid_drug_flag
	, SUM(p2.total_claim_count) AS tot_scripts
    , SUM(SUM(p2.total_claim_count)) OVER(PARTITION BY zc.county) AS tot_scripts_per_county
	, ROUND(SUM(p2.total_claim_count) / p3.population * 10000, 6) AS scripts_per_10k
	
FROM zip_to_county AS zc

JOIN prescriber AS p1
	ON p1.nppes_provider_zip5 = zc.zip

JOIN prescription AS p2
	ON p2.npi = p1.npi

JOIN drug AS d
	ON d.drug_name = p2.drug_name

JOIN population AS p3
	ON zc.fipscounty = p3.fipscounty

WHERE
	zc.rnk = 1
	--AND d.opioid_drug_flag = 'Y'

GROUP BY 1,2,3,4,5,6,7,8
ORDER BY 4 DESC
;
'''
drug_result = engine.execute(drug_query)

# %%
# read in the query results as a pandas dataframe
opioids = pd.read_sql(drug_query, con = engine)

# take a look at the overdoses dataframe
opioids.head()

# make sure the datatypes are correct in the overdoses dataframe
opioids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41131 entries, 0 to 41130
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   fipscounty                    41131 non-null  object
#  1   county                        41131 non-null  object
#  2   state                         41131 non-null  object
#  3   population                    41131 non-null  float64
#  4   generic_name                  41131 non-null  object
#  5   drug_group                    41131 non-null  object
#  6   opioid_drug_flag              41131 non-null  object
#  7   long_acting_opioid_drug_flag  41131 non-null  object
#  8   tot_scripts                   41131 non-null  float64
#  9   tot_scripts_per_county        41131 non-null  float64
#  10  scripts_per_10k               41131 non-null  float64
# dtypes: float64(4), object(7)
# memory usage: 3.5+ MB

# %%
# get OD data from the prescribers database
od_query = '''
SELECT
	fc.fipscounty
	, CASE WHEN cbsa.fipscounty IS NOT NULL THEN 'urban' ELSE 'rural' END AS county_type
	, od.overdose_deaths AS num_ods_2017
	, ROUND((od.overdose_deaths / p3.population * 10000), 6) AS od_rate_per_10K_2017

FROM overdose_deaths AS od

JOIN fips_county AS fc
	ON fc.fipscounty = od.fipscounty

JOIN population AS p3
	ON p3.fipscounty = od.fipscounty

LEFT JOIN cbsa
    ON cbsa.fipscounty = fc.fipscounty

WHERE od.year = 2017
AND fc.state = 'TN'
;
'''

# %%
# read in the query results as a pandas dataframe
ods = pd.read_sql(od_query, con = engine)

# take a look at the overdoses dataframe
ods.head()

# make sure the datatypes are correct in the overdoses dataframe
ods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fipscounty            95 non-null     object
#  1   county_type           95 non-null     object
#  2   num_ods_2017          95 non-null     float64
#  3   od_rate_per_10k_2017  95 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 3.1+ KB

# %%
# merge the overdoses and opioid prescription dataframes
# I opted to do this in python because...why not?
oao = opioids.merge(ods, how = 'inner', on = 'fipscounty')

# take a look at the merged dataframe
oao.head()

# check the datatypes
oao.info()

# check to make sure no counties went missing in the join
oao.county.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41131 entries, 0 to 41130
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   fipscounty                    41131 non-null  object
#  1   county                        41131 non-null  object
#  2   state                         41131 non-null  object
#  3   population                    41131 non-null  float64
#  4   generic_name                  41131 non-null  object
#  5   drug_group                    41131 non-null  object
#  6   opioid_drug_flag              41131 non-null  object
#  7   long_acting_opioid_drug_flag  41131 non-null  object
#  8   tot_scripts                   41131 non-null  float64
#  9   tot_scripts_per_county        41131 non-null  float64
#  10  scripts_per_10k               41131 non-null  float64
#  11  county_type                   41131 non-null  object
#  12  num_ods_2017                  41131 non-null  float64
#  13  od_rate_per_10k_2017          41131 non-null  float64
# dtypes: float64(6), object(8)
# memory usage: 4.7+ MB
# 95

# %% [markdown]
# ### Take a look at some correlations related to opioid drugs

# %%
# generate a correlations matrix
oao[oao['opioid_drug_flag'] == 'Y'].corr()
# Out:
#                         population  tot_scripts  tot_scripts_per_county  \
# population                1.000000     0.280214                0.947251
# tot_scripts               0.280214     1.000000                0.304586
# tot_scripts_per_county    0.947251     0.304586                1.000000
# scripts_per_10k          -0.080190     0.480700               -0.054533
# num_ods_2017              0.910905     0.283490                0.930639
# od_rate_per_10k_2017      0.236303     0.090853                0.283545
#
#                         scripts_per_10k  num_ods_2017  od_rate_per_10k_2017
# population                    -0.080190      0.910905              0.236303
# tot_scripts                    0.480700      0.283490              0.090853
# tot_scripts_per_county        -0.054533      0.930639              0.283545
# scripts_per_10k                1.000000     -0.069313             -0.036091
# num_ods_2017                  -0.069313      1.000000              0.426827
# od_rate_per_10k_2017          -0.036091      0.426827              1.000000

# %%
# take a look at the correlations matrix for long-acting opioids
oao[(oao['long_acting_opioid_drug_flag'] == 'Y') & (oao['opioid_drug_flag'] == 'Y')].corr()
# Out:
#                         population  tot_scripts  tot_scripts_per_county  \
# population                1.000000     0.381237                0.943982
# tot_scripts               0.381237     1.000000                0.420128
# tot_scripts_per_county    0.943982     0.420128                1.000000
# scripts_per_10k          -0.074062     0.447211               -0.041840
# num_ods_2017              0.910619     0.421151                0.927083
# od_rate_per_10k_2017      0.234687     0.154211                0.279785
#
#                         scripts_per_10k  num_ods_2017  od_rate_per_10k_2017
# population                    -0.074062      0.910619              0.234687
# tot_scripts                    0.447211      0.421151              0.154211
# tot_scripts_per_county        -0.041840      0.927083              0.279785
# scripts_per_10k                1.000000     -0.050676              0.005068
# num_ods_2017                  -0.050676      1.000000              0.426706
# od_rate_per_10k_2017           0.005068      0.426706              1.000000

# %%
# take a look at the correlations matrix for short-acting opioids
oao[(oao['long_acting_opioid_drug_flag'] == 'N') & (oao['opioid_drug_flag'] == 'Y')].corr()
# Out:
#                         population  tot_scripts  tot_scripts_per_county  \
# population                1.000000     0.333807                0.949644
# tot_scripts               0.333807     1.000000                0.362734
# tot_scripts_per_county    0.949644     0.362734                1.000000
# scripts_per_10k          -0.099800     0.458649               -0.065761
# num_ods_2017              0.911147     0.331167                0.933288
# od_rate_per_10k_2017      0.237514     0.103495                0.286347
#
#                         scripts_per_10k  num_ods_2017  od_rate_per_10k_2017
# population                    -0.099800      0.911147              0.237514
# tot_scripts                    0.458649      0.331167              0.103495
# tot_scripts_per_county        -0.065761      0.933288              0.286347
# scripts_per_10k                1.000000     -0.089006             -0.051158
# num_ods_2017                  -0.089006      1.000000              0.426929
# od_rate_per_10k_2017          -0.051158      0.426929              1.000000

# %%
# get a list of the generic drugs in the prescribers database with the number of entries for each
oao.groupby(['opioid_drug_flag','drug_group','long_acting_opioid_drug_flag']).size()
# Out:
# opioid_drug_flag  drug_group          long_acting_opioid_drug_flag
# N                 NOT AN OPIOID       N                               39731
# Y                 HYDROCODONE (ALL)   N                                 126
#                                       Y                                  20
#                   METHADONE (ALL)     Y                                  57
#                   NOT A TOP 3 OPIOID  N                                 486
#                                       Y                                 423
#                   OXYCODONE (ALL)     N                                 191
#                                       Y                                  97
# dtype: int64

# %%
# take a look at the correlations matrix for some specific opioids
oao[oao['long_acting_opioid_drug_flag'] == 'N'].corr()
# Out:
#                         population  tot_scripts  tot_scripts_per_county  \
# population                1.000000     0.240359                0.950676
# tot_scripts               0.240359     1.000000                0.255174
# tot_scripts_per_county    0.950676     0.255174                1.000000
# scripts_per_10k          -0.094118     0.455681               -0.076646
# num_ods_2017              0.912538     0.233977                0.933332
# od_rate_per_10k_2017      0.241668     0.072785                0.288978
#
#                         scripts_per_10k  num_ods_2017  od_rate_per_10k_2017
# population                    -0.094118      0.912538              0.241668
# tot_scripts                    0.455681      0.233977              0.072785
# tot_scripts_per_county        -0.076646      0.933332              0.288978
# scripts_per_10k                1.000000     -0.084914             -0.045480
# num_ods_2017                  -0.084914      1.000000              0.430168
# od_rate_per_10k_2017          -0.045480      0.430168              1.000000

# %% [markdown]
# ### Create some visualizations

# %%
# create a boxplot to see how frequently different opioids are typically prescribed
fig = px.box(oao[oao['opioid_drug_flag'] == 'Y'],
                 x = 'generic_name',
                 y = 'scripts_per_10k'
            )
fig.show()
# Out:
# <div>                            <div id="770e79e2-6024-4667-8a11-4f5683eb3a4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("770e79e2-6024-4667-8a11-4f5683eb3a4f")) {                    Plotly.newPlot(                        "770e79e2-6024-4667-8a11-4f5683eb3a4f",                        [{"alignmentgroup": "True", "hovertemplate": "generic_name=%{x}<br>scripts_per_10k=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["FENTANYL", "HYDROCODONE BITARTRATE", "HYDROCODONE/ACETAMINOPHEN", "HYDROCODONE/IBUPROFEN", "HYDROMORPHONE HCL", "HYDROMORPHONE HCL", "MEPERIDINE HCL", "METHADONE HCL", "MORPHINE SULFATE", "MORPHINE SULFATE", "MORPHINE SULFATE/NALTREXONE", "OXYCODONE HCL", "OXYCODONE HCL", "OXYCODONE HCL/ACETAMINOPHEN", "OXYCODONE MYRISTATE", "OXYMORPHONE HCL", "OXYMORPHONE HCL", "TAPENTADOL HCL", "TAPENTADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL/ACETAMINOPHEN", "ACETAMINOPHEN WITH CODEINE", "ACETAMINOPHEN/CAFF/DIHYDROCOD", "BUPRENORPHINE", "BUTORPHANOL TARTRATE", "CODEINE SULFATE", "CODEINE/BUTALBITAL/ASA/CAFFEIN", "FENTANYL", "HYDROCODONE BITARTRATE", "HYDROCODONE/ACETAMINOPHEN", "HYDROCODONE/IBUPROFEN", "HYDROMORPHONE HCL", "HYDROMORPHONE HCL", "ACETAMINOPHEN WITH CODEINE", "BUPRENORPHINE", "BUTALBIT/ACETAMIN/CAFF/CODEINE", "BUTORPHANOL TARTRATE", "CODEINE SULFATE", "CODEINE/BUTALBITAL/ASA/CAFFEIN", "MORPHINE SULFATE/NALTREXONE", "MORPHINE SULFATE", "MORPHINE SULFATE", "TRAMADOL HCL/ACETAMINOPHEN", "TRAMADOL HCL", "TRAMADOL HCL", "TAPENTADOL HCL", "TAPENTADOL HCL", "PENTAZOCINE HCL/NALOXONE HCL", "OXYMORPHONE HCL", "OXYMORPHONE HCL", "OXYCODONE MYRISTATE", "OXYCODONE HCL/ACETAMINOPHEN", "OXYCODONE HCL", "OXYCODONE HCL", "METHADONE HCL", "MEPERIDINE HCL", "FENTANYL", "ACETAMINOPHEN WITH CODEINE", "ACETAMINOPHEN/CAFF/DIHYDROCOD", "BUPRENORPHINE", "BUTALBIT/ACETAMIN/CAFF/CODEINE", "BUTORPHANOL TARTRATE", "CODEINE/BUTALBITAL/ASA/CAFFEIN", "MEPERIDINE HCL", "METHADONE HCL", "MORPHINE SULFATE", "MORPHINE SULFATE", "MORPHINE SULFATE/NALTREXONE", "OXYCODONE HCL", "OXYCODONE HCL", "OXYCODONE HCL/ACETAMINOPHEN", "OXYCODONE MYRISTATE", "OXYMORPHONE HCL", "OXYMORPHONE HCL", "PENTAZOCINE HCL/NALOXONE HCL", "TAPENTADOL HCL", "TAPENTADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL/ACETAMINOPHEN", "HYDROMORPHONE HCL", "HYDROMORPHONE HCL", "HYDROCODONE/IBUPROFEN", "HYDROCODONE/ACETAMINOPHEN", "HYDROCODONE BITARTRATE", "OXYMORPHONE HCL", "OXYMORPHONE HCL", "OXYCODONE MYRISTATE", "OXYCODONE HCL/ASPIRIN", "OXYCODONE HCL/ACETAMINOPHEN", "OXYCODONE HCL", "OXYCODONE HCL", "MORPHINE SULFATE/NALTREXONE", "MORPHINE SULFATE", "MORPHINE SULFATE", "METHADONE HCL", "MEPERIDINE HCL", "HYDROMORPHONE HCL", "HYDROMORPHONE HCL", "HYDROCODONE/IBUPROFEN", "HYDROCODONE/ACETAMINOPHEN", "HYDROCODONE BITARTRATE", "FENTANYL", "CODEINE/BUTALBITAL/ASA/CAFFEIN", "ACETAMINOPHEN WITH CODEINE", "BUPRENORPHINE", "BUTALBIT/ACETAMIN/CAFF/CODEINE", "BUTORPHANOL TARTRATE", "TRAMADOL HCL/ACETAMINOPHEN", "TRAMADOL HCL", "TRAMADOL HCL", "TAPENTADOL HCL", "TAPENTADOL HCL", "MORPHINE SULFATE/NALTREXONE", "MORPHINE SULFATE", "MORPHINE SULFATE", "METHADONE HCL", "HYDROMORPHONE HCL", "HYDROMORPHONE HCL", "HYDROCODONE/ACETAMINOPHEN", "HYDROCODONE BITARTRATE", "FENTANYL", "FENTANYL", "BUTORPHANOL TARTRATE", "ACETAMINOPHEN WITH CODEINE", "BUPRENORPHINE", "TAPENTADOL HCL", "TAPENTADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL", "TRAMADOL HCL/ACETAMINOPHEN", "OXYMORPHONE HCL", "OXYMORPHONE HCL", "OXYCODONE HCL/ACETAMINOPHEN", "OXYCODONE HCL", "OXYCODONE HCL", "HYDROMORPHONE HCL", "HYDROMORPHONE HCL", "HYDROCODONE/ACETAMINOPHEN", "HYDROCODONE BITARTRATE", "FENTANYL", "BUTORPHANOL TARTRATE", "BUTALBIT/ACETAMIN ...

# %%
oao_grouped = oao.groupby(['county','drug_group', 'num_ods_2017', 'population', 'tot_scripts_per_county'])[['tot_scripts']].sum().reset_index()

# %%
oao_grouped.head()
# Out:
#      county          drug_group  num_ods_2017  population  \
# 0  ANDERSON   HYDROCODONE (ALL)          34.0     75538.0
# 1  ANDERSON  NOT A TOP 3 OPIOID          34.0     75538.0
# 2  ANDERSON       NOT AN OPIOID          34.0     75538.0
# 3  ANDERSON     OXYCODONE (ALL)          34.0     75538.0
# 4   BEDFORD   HYDROCODONE (ALL)           3.0     46854.0
#
#    tot_scripts_per_county  tot_scripts
# 0                532145.0      14227.0
# 1                532145.0       7556.0
# 2                532145.0     497263.0
# 3                532145.0      13099.0
# 4                157650.0       4703.0

# %%
oao_grouped['ods_per_10k'] = oao_grouped['num_ods_2017'] / oao_grouped['population'] * 10000
oao_grouped['scripts_per_10k'] = oao_grouped['tot_scripts'] / oao_grouped['population'] * 10000

# %%
oao_grouped.head(20)
# Out:
#       county          drug_group  num_ods_2017  population  tot_scripts  \
# 0   ANDERSON   HYDROCODONE (ALL)          34.0     75538.0      14227.0
# 1   ANDERSON  NOT A TOP 3 OPIOID          34.0     75538.0       7556.0
# 2   ANDERSON       NOT AN OPIOID          34.0     75538.0     497263.0
# 3   ANDERSON     OXYCODONE (ALL)          34.0     75538.0      13099.0
# 4    BEDFORD   HYDROCODONE (ALL)           3.0     46854.0       4703.0
# 5    BEDFORD  NOT A TOP 3 OPIOID           3.0     46854.0       2053.0
# 6    BEDFORD       NOT AN OPIOID           3.0     46854.0     149361.0
# 7    BEDFORD     OXYCODONE (ALL)           3.0     46854.0       1533.0
# 8     BENTON   HYDROCODONE (ALL)           5.0     16154.0       4804.0
# 9     BENTON     METHADONE (ALL)           5.0     16154.0         59.0
# 10    BENTON  NOT A TOP 3 OPIOID           5.0     16154.0       2486.0
# 11    BENTON       NOT AN OPIOID           5.0     16154.0      55684.0
# 12    BENTON     OXYCODONE (ALL)           5.0     16154.0       3368.0
# 13   BLEDSOE   HYDROCODONE (ALL)           2.0     14413.0       1978.0
# 14   BLEDSOE  NOT A TOP 3 OPIOID           2.0     14413.0        690.0
# 15   BLEDSOE       NOT AN OPIOID           2.0     14413.0      50663.0
# 16   BLEDSOE     OXYCODONE (ALL)           2.0     14413.0        638.0
# 17    BLOUNT   HYDROCODONE (ALL)          29.0    127135.0      13769.0
# 18    BLOUNT     METHADONE (ALL)          29.0    127135.0         12.0
# 19    BLOUNT  NOT A TOP 3 OPIOID          29.0    127135.0       7573.0
#
#     ods_per_10k  scripts_per_10k
# 0      4.501046      1883.422913
# 1      4.501046      1000.291244
# 2      4.501046     65829.516270
# 3      4.501046      1734.094098
# 4      0.640287      1003.756350
# 5      0.640287       438.169633
# 6      0.640287     31877.961327
# 7      0.640287       327.186580
# 8      3.095209      2973.876439
# 9      3.095209        36.523462
# 10     3.095209      1538.937724
# 11     3.095209     34470.719326
# 12     3.095209      2084.932524
# 13     1.387636      1372.372164
# 14     1.387636       478.734476
# 15     1.387636     35150.905433
# 16     1.387636       442.655936
# 17     2.281040      1083.021985
# 18     2.281040         0.943879
# 19     2.281040       595.666024

# %%
oao_regrouped = oao.groupby(['county','opioid_drug_flag', 'num_ods_2017', 'population'])[['tot_scripts']].sum().reset_index()

# %%
oao_regrouped.head()
# Out:
#      county opioid_drug_flag  num_ods_2017  population  tot_scripts
# 0  ANDERSON                N          34.0     75538.0     497263.0
# 1  ANDERSON                Y          34.0     75538.0      34882.0
# 2   BEDFORD                N           3.0     46854.0     149361.0
# 3   BEDFORD                Y           3.0     46854.0       8289.0
# 4    BENTON                N           5.0     16154.0      55684.0

# %%
oao_regrouped['ods_per_10k'] = oao_regrouped['num_ods_2017'] / oao_regrouped['population'] * 10000
oao_regrouped['scripts_per_10k'] = oao_regrouped['tot_scripts'] / oao_regrouped['population'] * 10000

# %%
oao_regrouped.head()
# Out:
#      county opioid_drug_flag  num_ods_2017  population  tot_scripts  \
# 0  ANDERSON                N          34.0     75538.0     497263.0
# 1  ANDERSON                Y          34.0     75538.0      34882.0
# 2   BEDFORD                N           3.0     46854.0     149361.0
# 3   BEDFORD                Y           3.0     46854.0       8289.0
# 4    BENTON                N           5.0     16154.0      55684.0
#
#    ods_per_10k  scripts_per_10k  pct_tot_scripts_per_county
# 0     4.501046     65829.516270                         NaN
# 1     4.501046      4617.808255                         NaN
# 2     0.640287     31877.961327                         NaN
# 3     0.640287      1769.112562                         NaN
# 4     3.095209     34470.719326                         NaN

# %%
# create a boxplot to see how frequently long-acting vs. short-acting opioids are typically prescribed
fig = px.box(oao[oao['opioid_drug_flag'] == 'Y'],
                 x = 'long_acting_opioid_drug_flag',
                 y = 'scripts_per_10k'
            )
fig.show()
# Out:
# <div>                            <div id="81b52a7a-2bd9-4277-8ca4-5afee6255d95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81b52a7a-2bd9-4277-8ca4-5afee6255d95")) {                    Plotly.newPlot(                        "81b52a7a-2bd9-4277-8ca4-5afee6255d95",                        [{"alignmentgroup": "True", "hovertemplate": "long_acting_opioid_drug_flag=%{x}<br>scripts_per_10k=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["Y", "Y", "N", "N", "N", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "N", "N", "Y", "N", "N", "N", "Y", "Y", "N", "N", "N", "Y", "N", "Y", "N", "N", "N", "N", "Y", "Y", "N", "N", "Y", "N", "Y", "N", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "N", "Y", "N", "N", "N", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "N", "Y", "N", "Y", "N", "Y", "N", "N", "N", "Y", "Y", "N", "Y", "N", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "N", "N", "N", "Y", "Y", "N", "N", "Y", "N", "N", "N", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "Y", "N", "N", "Y", "Y", "N", "N", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "N", "Y", "N", "Y", "N", "N", "Y", "Y", "N", "N", "Y", "N", "Y", "N", "Y", "N", "N", "Y", "N", "N", "Y", "Y", "N", "N", "Y", "N", "Y", "N", "N", "N", "Y", "N", "N", "Y", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "N", "N", "N", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "N", "Y", "N", "N", "Y", "N", "N", "Y", "Y", "N", "N", "Y", "Y", "N", "N", "Y", "Y", "N", "N", "N", "Y", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "N", "Y", "Y", "N", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "N", "Y", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "N", "N", "Y", "N", "N", "N", "Y", "N", "Y", "Y", "N", "N", "N", "Y", "Y", "N", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "N", "N", "Y", "N", "Y", "N", "N", "N", "Y", "Y", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "N", "N", "Y", "N", "Y", "N", "N", "Y", "N", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "N", "N", "Y", "Y", "N", "Y", "N", "N", "Y", "N", "Y", "N", "Y", "N", "N", "Y", "N", "N", "N", "Y", "N", "Y", "N", "N", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "N", "N", "N", "Y", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "N", "Y", "Y", "Y", "N", "Y", "N", "N", "N", "Y", "N", "N", "N", "Y", "Y", "Y", "N", "N", "N", "N", "Y", "N", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "N", "N", "Y", "N", "N", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "N", "N", "N", "Y", "N", "Y", "Y", "Y", "Y", "N", "N", "N", "N", "N", "Y", "N", "N", "N", "Y", "N", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "Y", "Y", "N", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "N", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "N", "Y", "N", "Y", "Y", "N", "Y", "Y", "N", "N", "Y", "Y", "N", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "N", "Y", "N", "Y", "N", "N", "Y", "N", "N", "N", "N", "Y", "N", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "N", "N", "Y", "N", "Y", "N", "N", "Y", "N", "N", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "N", "N", "Y", "N", "N", "Y", "N", "Y", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "N", "N", "N", "N", "Y", "N", "Y", "N", "N", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "N", "N", "N", "N", "N", "Y", "N", "N", "Y", "N", "Y", "N", "N", "Y", "N", "Y", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "N", "Y", "N", "Y", "Y", "N", "Y", "N", "Y", "Y", "N", "N", "Y", "N", "Y", "N", "N ...

# %%
oao.groupby('long_acting_opioid_drug_flag')['tot_scripts'].sum()
# Out:
# long_acting_opioid_drug_flag
# N    37987645.0
# Y      296044.0
# Name: tot_scripts, dtype: float64
